# %% [markdown]
# # Trabajo final HCC

# %% [markdown]
# Leempos nuestro archivo y vemos que datos tenemos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ipyvolume as ipv
from ipywidgets import interact, interact_manual, widgets

sns.set_style('whitegrid')

# %matplotlib inline

data=pd.read_csv(r'/home/anakin/Documents/HCC/asu.tsv', sep='|')

# %%
data.head(150000)
# Out:
#               X        Y        Z     RAJ2000    DEJ2000         z
# 0      -0.10366  0.01857 -0.00193  169.842883  -1.052567  0.105326
# 1      -0.07651  0.01131 -0.00142  171.592147  -1.054439  0.077352
# 2      -0.07156  0.01369 -0.00027  169.167949  -0.211055  0.072861
# 3      -0.10111  0.01884 -0.00038  169.447759  -0.214535  0.102854
# 4      -0.10696  0.00161 -0.00039  179.135726  -0.211295  0.106975
# ...         ...      ...      ...         ...        ...       ...
# 146107 -0.09209  0.02906  0.01642  162.486864   9.651224  0.097955
# 146108 -0.09187  0.02883  0.01634  162.577575   9.628749  0.097664
# 146109 -0.08247  0.02693  0.01512  161.916365   9.889721  0.088059
# 146110 -0.09290  0.03025  0.01698  161.961011   9.860375  0.099168
# 146111 -0.07300  0.02361  0.01358  162.079082  10.040918  0.077914
#
# [146112 rows x 6 columns]

# %%
rs=data['z']

c=299792
H=72
dist=rs*c/H

print(dist);
# Out:
# 0         438.554058
# 1         322.076539
# 2         303.377013
# 3         428.261200
# 4         445.420128
#              ...
# 146107    407.862852
# 146108    406.651193
# 146109    366.658107
# 146110    412.913515
# 146111    324.416582
# Name: z, Length: 146112, dtype: float64

# %%
fig, ax=plt.subplots(1,1)

x=data['X']
y=data['Y']
z=data['Z']
alfa=data['RAJ2000']
delta=data['DEJ2000']
plt.scatter(x,z,s=0.05);

#print(x,y,z)

# %%
def spheres(x0, y0, z0, radio):
h=0.6767
#radio=500/h
d=np.zeros(N)
gc=0

for i in range(N):
    
    d[i]=np.sqrt((x[i]-x0)**2+(y[i]-y0)**2+(z[i]-z0)**2)
        
    if (d[i]<=radio and d[i]!=0):
        
    gc+=1
    
return dens
